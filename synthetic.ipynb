# %% [markdown]
# # Visualizing Data in Jupyter Notebooks, using Synthetic Forms
# <br>
# This is a simple overview of how Python visualization libraries such as Matplotlib, Plotly, and Mayavi can be used to create and analyze synthetic data in a Jupyter notebook. The example code provided should be used as a starting point and can be modified to suit the specific needs of your project. It is important to keep in mind that the visualization of synthetic data can be computationally expensive and it is important to be mindful of the size of the data and use appropriate techniques for handling and visualizing large datasets.
# <br>
# <br>
# So excited to learn how to use NumPy in Jupyter Notebooks!
# NumPy is a powerful Python library that enables us to create, manipulate and analyze 3D matrix cubes of data—from subjective personal data found on social media, to objective scientific data and even financial market data. It's like having an amazing toolkit for solving complicated problems without having to learn an entirely new language. And the best part? It's totally free! So what are you waiting for? Let's get started with NumPy and see what kind of insights we can uncover!<br><br>
#
# ## Synthetic Data, Example 1
#
# <hr>
# Import the required libraries

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %% [markdown]
# Create a synthetic dataset with 100 samples.

# %%
num_samples = 100
x = np.linspace(1, 10, num_samples)
y = x + np.random.normal(0, 1, num_samples)

# %% [markdown]
# Create an object with the x and y values and create a DataFrame using the Pandas library.

# %%
data = {'x': x, 
        'y': y} 
df = pd.DataFrame(data)

# %% [markdown]
# Plot the scatterplot of the data using the Matplotlib library.

# %%
plt.scatter(df['x'], df['y']) 
plt.title("Scatter plot of Synthetic Data")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Use the t-test to determine if there is a significant difference between the two groups.

# %%
from scipy import stats
t_test = stats.ttest_ind(df['x'], df['y'])

# %% [markdown]
# If the resulting value is greater than the critical value at the specified confidence level, then we can reject the null hypothesis and conclude that there is a significant difference between the two groups.

# %% [markdown]
# ## Synthetic Data, Example 2
#    1. Generate the synthetic data for 100 sample sets using NumPy, and store it in a variable.
#    2. Create two separate functions, one for compile-time data rendering and one for real-time data rendering. The function for compile-time data rendering would use the synthetic data that was generated at the beginning, and the function for real-time data rendering would use the same data but accessed during runtime.
#    3. Measure the performance of each function by measuring the time it takes for each function to execute using the time() function in python.
#    4. Create a synthetic plot using Matplotlib to visualize the differences in performance between the two methods. The plot should show the time taken by each function in executing the task and the differences between the two methods.
#    5. Use the Matplotlib library to create a synthetic plot that will help demonstrate the differences between the two data rendering approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# Generate synthetic data for 100 sample sets
data = np.random.rand(100, 2)

# Create a function for compile-time data rendering
def compile_time_rendering(data):
    start_time = time.time()
    # Perform some operation on the data (for example, calculating the mean)
    result = np.mean(data, axis=0)
    end_time = time.time()
    return end_time - start_time

# Create a function for real-time data rendering
def real_time_rendering(data):
    start_time = time.time()
    # Perform the same operation on the data (for example, calculating the mean)
    result = np.mean(data, axis=0)
    end_time = time.time()
    return end_time - start_time

# Measure the performance of each function
compile_time = compile_time_rendering(data)
real_time = real_time_rendering(data)

# Create a synthetic plot to visualize the differences in performance
plt.bar(['Compile-time', 'Real-time'], [compile_time, real_time])
plt.ylabel('Execution Time (seconds)')
plt.show()

# %% [markdown]
# ## Example 3, Synthetic 3d Matrix
# Here's an example of how you might create a synthetic 3D matrix cube of data and plot it in a Jupyter notebook:

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic 3D matrix cube of data
data = np.random.rand(10, 10, 10)

# Plot the data using Matplotlib
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0], data[:, 1], data[:, 2])
plt.show()

# %% [markdown]
# This code generates a 10x10x10 matrix cube of random data using NumPy, and then plots it using Matplotlib in 3D space.
#
# You can also use other libraries such as Plotly, Mayavi, etc. to plot and visualize the synthetic 3D matrix cubes of data.
#
# Once you have plotted the data, you can then perform various analysis on it, such as calculating the mean, median, standard deviation, etc. You can also slice the data to look at specific parts of it, or plot specific slices of the data.
# <hr><br>
# Please note that the specific implementation will depend on the size and structure of your data, as well as the specific requirements of your project. In addition to the above code snippet, you can also add other functionalities such as axis labels, change the color, size, and shape of the plotted data, and add different types of plots. You can also use the Matplotlib's or Plotly's built-in functions to create interactive visualizations of the 3D matrix cubes of data.
#
# It's also worth noting that 3D matrix cubes of data are typically large, and visualizing and analyzing them can be computationally expensive. Therefore, it's important to be mindful of the size of your data and use appropriate techniques for handling and visualizing large datasets.
#
# Overall, by using Jupyter notebook, NumPy and Matplotlib or Plotly, you can create and analyze synthetic 3D matrix cubes of data effectively.
